# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
assert sys.version_info >= (3, 5)
import sklearn
assert sklearn.__version__ >= "0.20"
import numpy as np
import seaborn as sns
from sklearn.model_selection import StratifiedShuffleSplit
import warnings
warnings.filterwarnings(action='ignore')
plt.rcParams['font.family'] = 'AppleGothic' # For Mac

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
data = pd.read_csv("/Users/csb/Desktop/Project/넙치 머신러닝/0_양식어류 질병예측_221207/20-21 전처리.csv")

# %%
from scipy.stats import mannwhitneyu

# %%
feature_list = []
for i in range(len(data.columns)-1):
    print(data.columns[i])
    udata = data.iloc[:,[i,-1]]
    jeong = udata[udata['결과'] == '정상']
    jeong = jeong.drop(['결과'],axis=1)
    jooE = udata[udata['결과'] == '주의']
    jooE = jooE.drop(['결과'],axis=1)
    zeel = udata[udata['결과'] == '질병']
    zeel = zeel.drop(['결과'],axis=1)

    U1, p = mannwhitneyu(jeong, jooE)
    U2, p2 = mannwhitneyu(jooE, zeel)
    U3, p3 = mannwhitneyu(zeel, jeong)
    print(p,p2,p3)
    if p<(0.05/3) and p2<(0.05/3) and p3<(0.05/3):
        feature_list.append(udata.columns[0])
# Out:
# 일순환량
# 6.171512839909593e-07 0.08632187249559936 2.3964978781518667e-08
# 사료종류
# 0.15971226770767627 0.44311681321674407 0.24638703843920023
# 사료급이량
# 0.1615321544375894 0.02451283763456593 0.04473614764380605
# 일평균폐사
# 0.1955631981408184 8.120313033547055e-07 3.4290752093586976e-07
# 백신접종여부
# 0.38372311655419045 0.3054122433694596 0.4256026908093137
# 수온
# 1.1762445620342888e-10 1.7299367775514515e-06 1.8574026935762876e-21
# 전장(cm)
# 0.1299151704644917 2.1195961787800685e-06 6.134162108864069e-07
# 체장(cm)
# 0.4983626626929635 0.00016951264263733706 0.0007098987735399819
# 어체중(g)
# 0.01272720647817358 1.748122142014953e-08 8.298822370876277e-11
# Condition factor
# 6.840213485572133e-13 1.7084965050896187e-12 8.612924235813012e-26
# 심장질환
# 0.1984457566440695 4.2656720219750575e-08 1.537632128547276e-05
# 신장질환
# 0.1357614959364084 4.728800472452883e-10 3.269411082977835e-06
# 비장질환
# 0.0916577286825127 5.703937189256289e-07 5.262256377841956e-06
# 간장질환
# ...

# %%
feature_list

# %%
#V.~,  whkr4, whkr6, Wlr4 삭제
