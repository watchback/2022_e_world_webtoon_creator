# %%
import pandas as pd
data = pd.read_csv("/Users/csb/Desktop/Project/넙치 머신러닝/0_양식어류 질병예측_221207/20-21-22-23 통합본 Raw 복사본.csv")

# %%
from pycaret.classification import *
from sklearn.model_selection import LeaveOneOut

# %%
data
# Out:
#       일순환량 사료종류   사료급이량  일평균폐사 백신접종여부     수온   DO    pH    ATP     세균수  ...  \
# 0     20.0   EP  0.0075   30.0      Ⅹ  12.44  7.5  6.97  146.0  4400.0  ...
# 1     20.0   EP  0.0075   30.0      Ⅹ  12.44  7.5  6.97  146.0  4400.0  ...
# 2     20.0   EP  0.0075   30.0      Ⅹ  12.44  7.5  6.97  146.0  4400.0  ...
# 3     20.0   EP  0.0075   30.0      Ⅹ  12.44  7.5  6.97  146.0  4400.0  ...
# 4     20.0   EP  0.0075   30.0      Ⅹ  12.44  7.5  6.97  146.0  4400.0  ...
# ...    ...  ...     ...    ...    ...    ...  ...   ...    ...     ...  ...
# 1266   NaN  NaN     NaN    NaN    NaN  23.30  NaN   NaN    NaN     NaN  ...
# 1267   NaN  NaN     NaN    NaN    NaN  23.30  NaN   NaN    NaN     NaN  ...
# 1268   NaN  NaN     NaN    NaN    NaN  23.30  NaN   NaN    NaN     NaN  ...
# 1269   NaN  NaN     NaN    NaN    NaN  23.30  NaN   NaN    NaN     NaN  ...
# 1270   NaN  NaN     NaN    NaN    NaN  23.30  NaN   NaN    NaN     NaN  ...
#
# ...

# %%
#data = data[['수온', 'Condition factor', 'ALP', 'T P', 'Wgp2', 'Wgi3', 'Whkp2', 'Whki2-1', 'Wlr1', 'Wlr2-1', 'Wsi2', 'Whi6-1','결과']]
#data = data[ ['사료급이량', '어체중(g)', 'Condition factor', '임상증상유무', 'T P', 'Wgp2', 'Whkr7', 'Whkp2', 'Whki2-1', 'Wlr1', 'Wlr2-1', 'Wsi2','결과']]
#data = data[['사료급이량','백신접종여부', 'DO', '임상증상유무', '기생충유무', 'BUN', 'CREA', 'GLU', 'Whkr7', 'Whkp2', 'Whki2-1', 'Wlr2-1', 'Wsi2','결과']]
#data = data[['사료급이량', '어체중(g)', 'Condition factor', '임상증상유무', 'BUN', 'T P', 'CHOL', 'ALB', 'Wgp2', 'Whkr7', 'Whkp2', 'Whki2-1', 'Wlr1', 'Wlr2-1', 'Wsi2','결과']]
#data = data[['사료급이량', 'DO', '어체중(g)', 'Condition factor', '임상증상유무', 'ALP', 'BUN', 'GLU', 'T P', 'CHOL', 'ALB', 'Wgp2', 'Whkr7', 'Whkp2', 'Whki2-1', 'Wlr1', 'Wlr2-1', 'Wsi2','결과']]
#data = data[['수온', 'Condition factor', 'ALP', 'T P', 'Wgp2', 'Wgi3', 'Whkp2', 'Whki2-1', 'Wlr1', 'Wlr2-1', 'Wsi2', 'Whi6-1','결과']]

data
# Out:
#        사료급이량   DO  어체중(g)  Condition factor  임상증상유무  ALP   BUN  GLU  T P  \
# 0     0.0075  7.5   528.8             1.828       0   79   1.9   16  5.7
# 1     0.0075  7.5   515.4             2.348       0   60   2.2   17  5.4
# 2     0.0075  7.5   432.3             1.634       1   95   1.9   14  4.7
# 3     0.0075  7.5   573.4             1.906       0   77   2.4   11  5.7
# 4     0.0075  7.5   660.8             2.055       0   59   2.2   18  5.9
# ...      ...  ...     ...               ...     ...  ...   ...  ...  ...
# 1266  0.0597  8.0   376.0             1.900       0   68   7.7    3  3.7
# 1267  0.0597  8.0   376.0             1.900       0   36   9.5    3  2.4
# 1268  0.0597  8.0   376.0             1.900       0   78   5.5    2  3.5
# 1269  0.0597  8.0   376.0             1.900       0   45  13.9    3  3.2
# 1270  0.0597  8.0   376.0             1.900       0   36   9.3    3  2.9
#
#       CHOL  ALB  Wgp2  Whkr7  Whkp2  Whki2-1  Wlr1  Wlr2-1  Wsi2  결과
# ...

# %%
loocv = LeaveOneOut()

# %%
s = setup(data, target = '결과', session_id = 123,fix_imbalance = False, train_size=0.9)
#fold_strategy=loocv,
# Out:
# <style type="text/css">
# #T_60a31_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_60a31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60a31_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_60a31_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60a31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60a31_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_60a31_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_60a31_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_60a31_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_60a31_row1_col1" class="data row1 col1" >결과</td>
#     </tr>
#     <tr>
#       <th id="T_60a31_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_96a9f th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
