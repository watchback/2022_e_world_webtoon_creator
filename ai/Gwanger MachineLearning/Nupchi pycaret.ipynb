# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
assert sys.version_info >= (3, 5)
import sklearn
assert sklearn.__version__ >= "0.20"
import numpy as np
import seaborn as sns
from sklearn.model_selection import StratifiedShuffleSplit
import warnings
warnings.filterwarnings(action='ignore')
plt.rcParams['font.family'] = 'AppleGothic' # For Mac

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
data = pd.read_csv("/Users/csb/Desktop/Project/넙치 머신러닝/0_양식어류 질병예측_221207/20-21 전처리.csv")

# %%
data.shape
# Out:
# (890, 76)

# %%
#corr_matrix=data.corr()
#print(corr_matrix["결과"].sort_values(ascending=False))

# %%
dataset = data.sample(frac=0.9, random_state=9)
data_unseen = data.drop(data.index)

dataset.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(dataset.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (801, 76)
# Unseen Data For Predictions: (0, 76)

# %%
from pycaret.classification import *
from sklearn.model_selection import LeaveOneOut

loocv = LeaveOneOut()
exp_mclf101 = setup(data = data, target = '결과', session_id=9, fold_strategy=loocv, train_size=0.999)
# Out:
# <style type="text/css">
# #T_1a786_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1a786">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a786_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1a786_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a786_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a786_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1a786_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_1a786_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a786_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1a786_row1_col1" class="data row1 col1" >결과</td>
#     </tr>
#     <tr>
#       <th id="T_1a786_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
random_forest = create_model('rf')
# Out:
# IntProgress(value=0, description='Processing: ', max=4)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  15:56:32
# Status     . . . . . . . . . . . . . . . . . .         Fitting 889 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
# Empty DataFrame
# Columns: [Fold, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# ...

# %%
plt.rc("font", family = "AppleGothic")
evaluate_model(random_forest)
