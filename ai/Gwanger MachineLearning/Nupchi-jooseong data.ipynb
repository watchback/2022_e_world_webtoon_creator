# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
assert sys.version_info >= (3, 5)
import sklearn
assert sklearn.__version__ >= "0.20"
import numpy as np
import seaborn as sns
from sklearn.model_selection import StratifiedShuffleSplit
import warnings
warnings.filterwarnings(action='ignore')
plt.rcParams['font.family'] = 'AppleGothic' # For Mac

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
data = pd.read_csv("주성이형 데이터.csv", encoding='cp949')

# %%
corr_matrix=data.corr()
print(corr_matrix) #Pearson correlation 사용
#print(corr_matrix["결과"].sort_values(ascending=False))
# Out:
#                       일순환량      사료종류     사료급이량     일평균폐사    백신접종여부        수온  \
# 일순환량              1.000000 -0.310496  0.030591 -0.127801 -0.334822 -0.078898
# 사료종류             -0.310496  1.000000 -0.210829  0.109333  0.799571 -0.086709
# 사료급이량             0.030591 -0.210829  1.000000 -0.062503 -0.146424  0.177679
# 일평균폐사            -0.127801  0.109333 -0.062503  1.000000  0.175485 -0.273382
# 백신접종여부           -0.334822  0.799571 -0.146424  0.175485  1.000000  0.192628
# 수온               -0.078898 -0.086709  0.177679 -0.273382  0.192628  1.000000
# 전장(cm)           -0.007123  0.443418 -0.087306 -0.241338  0.393310  0.304288
# 체장(cm)            0.014551  0.490020 -0.125118 -0.205377  0.411285  0.207695
# 어체중(g)            0.097759  0.400955 -0.153070 -0.221269  0.386392  0.264707
# Condition factor -0.006424  0.061107  0.009229 -0.207523  0.139664  0.313440
# 심장질환              0.056051  0.005138 -0.032377 -0.043681 -0.008698 -0.047863
# ...

# %%
'''
data = data.drop(['척추만곡'], axis='columns')
data = data.drop(['MCHC'], axis='columns')
data = data.drop(['Wgc1'], axis='columns')
data = data.drop(['Wlr4'], axis='columns')
data = data.drop(['Wgr2'], axis='columns')
data = data.drop(['S. parauberis'], axis='columns')
data = data.drop(['Wlr8'], axis='columns')
data = data.drop(['Wlc1'], axis='columns')
data = data.drop(['Ilc'], axis='columns')
data = data.drop(['ALP'], axis='columns')
data = data.drop(['Wbkr1'], axis='columns')
data = data.drop(['pH'], axis='columns')
data = data.drop(['T P'], axis='columns')
data = data.drop(['V. ichthyoenteri'], axis='columns')
data = data.drop(['Whi6-3'], axis='columns')
data = data.drop(['Scuticocilliates'], axis='columns')
data = data.drop(['Wlr2-2'], axis='columns')
data = data.drop(['TBIL'], axis='columns')
data = data.drop(['ALB'], axis='columns')
data = data.drop(['HSI(%)'], axis='columns')
'''
# Out:
# "\ndata = data.drop(['척추만곡'], axis='columns')\ndata = data.drop(['MCHC'], axis='columns')\ndata = data.drop(['Wgc1'], axis='columns')\ndata = data.drop(['Wlr4'], axis='columns')\ndata = data.drop(['Wgr2'], axis='columns')\ndata = data.drop(['S. parauberis'], axis='columns')\ndata = data.drop(['Wlr8'], axis='columns')\ndata = data.drop(['Wlc1'], axis='columns')\ndata = data.drop(['Ilc'], axis='columns')\ndata = data.drop(['ALP'], axis='columns')\ndata = data.drop(['Wbkr1'], axis='columns')\ndata = data.drop(['pH'], axis='columns')\ndata = data.drop(['T P'], axis='columns')\ndata = data.drop(['V. ichthyoenteri'], axis='columns')\ndata = data.drop(['Whi6-3'], axis='columns')\ndata = data.drop(['Scuticocilliates'], axis='columns')\ndata = data.drop(['Wlr2-2'], axis='columns')\ndata = data.drop(['TBIL'], axis='columns')\ndata = data.drop(['ALB'], axis='columns')\ndata = data.drop(['HSI(%)'], axis='columns')\n"

# %%
data.shape
# Out:
# (890, 80)

# %%
dataset = data.sample(frac=0.9, random_state=786)
data_unseen = data.drop(data.index)

dataset.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(dataset.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (801, 80)
# Unseen Data For Predictions: (0, 80)

# %%
from pycaret.classification import *
exp_mclf101 = setup(data = data, target = '결과', session_id=123)
# Out:
# <style type="text/css">
# #T_e8d46_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e8d46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8d46_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e8d46_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8d46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8d46_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e8d46_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e8d46_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8d46_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e8d46_row1_col1" class="data row1 col1" >결과</td>
#     </tr>
#     <tr>
#       <th id="T_e8d46_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models(n_select=25,sort='Accuracy')
# Out:
# <style type="text/css">
# #T_62668 th {
#   text-align: left;
# }
# ...

# %%
plt.rc("font", family = "AppleGothic")
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
