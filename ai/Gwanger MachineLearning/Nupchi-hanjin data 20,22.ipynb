# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
assert sys.version_info >= (3, 5)
import sklearn
assert sklearn.__version__ >= "0.20"
import numpy as np
import seaborn as sns
from sklearn.model_selection import StratifiedShuffleSplit
import warnings
warnings.filterwarnings(action='ignore')
plt.rcParams['font.family'] = 'AppleGothic' # For Mac

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
data = pd.read_csv("20,22.csv")

# %%
data.shape
# Out:
# (688, 102)

# %%
data = data.dropna(axis=0)

# %%
corr_matrix=data.corr()
print(corr_matrix["결과"].sort_values(ascending=False))
# Out:
# 결과                  1.000000
# Whkp2               0.618793
# Wsi2                0.600509
# Wlr1                0.447730
# Wlr2-1              0.428306
# E. piscicida        0.426978
# Whki2-1             0.415332
# 임상증상유무              0.405737
# Wsi3-1              0.379393
# Wli3-2              0.369924
# 세균감염유무              0.353460
# GGT                 0.342806
# Wbkr5               0.324816
# BUN                 0.308574
# Whkr7               0.292319
# 복수                  0.290201
# Wlr6                0.277884
# Wii3                0.265836
# Wsti3               0.257269
# 비장질환                0.248483
# Whi6-1              0.223801
# Whi3                0.218130
# 신장질환                0.216494
# Wli3-1              0.212406
# 기타                  0.212212
# Wgr1                0.206695
# Wli6                0.206534
# 사료종류                0.199406
# 간장질환                0.199306
# Wbki3-2             0.196180
# Whkr4               0.186993
# 심장질환                0.186834
# ...

# %%
'''
data = data.drop(['Whkr4'], axis='columns')
data = data.drop(['체장(cm)'], axis='columns')
data = data.drop(['사료급이량'], axis='columns')
data = data.drop(['ALB'], axis='columns')
data = data.drop(['L. garvieae'], axis='columns')
data = data.drop(['Wlc1'], axis='columns')
data = data.drop(['P. damselae'], axis='columns')
data = data.drop(['Whr7'], axis='columns')
data = data.drop(['Wbkr2-2'], axis='columns')
data = data.drop(['안구질환'], axis='columns')
data = data.drop(['백신접종여부'], axis='columns')
data = data.drop(['Wlr2-2'], axis='columns')
data = data.drop(['사료종류'], axis='columns')
data = data.drop(['척추만곡'], axis='columns')
data = data.drop(['탈장'], axis='columns')
data = data.drop(['기타'], axis='columns')
data = data.drop(['Scuticocilliates'], axis='columns')
data = data.drop(['림포'], axis='columns')
data = data.drop(['Wlr8'], axis='columns')
data = data.drop(['Whi6-3'], axis='columns')
data = data.drop(['V. ichthyoenteri'], axis='columns')
data = data.drop(['Wlp1'], axis='columns')
data = data.drop(['Whkr6'], axis='columns')
data = data.drop(['S. parauberis'], axis='columns')
data = data.drop(['Whki2-2'], axis='columns')
data = data.drop(['gyrodactylus'], axis='columns')
data = data.drop(['Wgc1'], axis='columns')
---------------------------------------------------
data = data.drop(['E. piscicida'], axis='columns')
data = data.drop(['Whkr7'], axis='columns')
data = data.drop(['Wbki3-2'], axis='columns')
data = data.drop(['일순환량'], axis='columns')
data = data.drop(['일평균폐사'], axis='columns')
data = data.drop(['복수'], axis='columns')
data = data.drop(['비장질환'], axis='columns')
data = data.drop(['Wbkr2-1'], axis='columns')
data = data.drop(['ameoba'], axis='columns')
data = data.drop(['Wsr6'], axis='columns')
data = data.drop(['심장질환'], axis='columns')
data = data.drop(['빈혈'], axis='columns')
data = data.drop(['Wbki3-1'], axis='columns')
data = data.drop(['세균감염유무'], axis='columns')
data = data.drop(['Whi6-2'], axis='columns')
data = data.drop(['Wbkr6'], axis='columns')
data = data.drop(['기생충유무'], axis='columns')
data = data.drop(['Wbkr1'], axis='columns')
data = data.drop(['Wlr4'], axis='columns')
data = data.drop(['Wsr5'], axis='columns')
data = data.drop(['아가미부식'], axis='columns')
data = data.drop(['Wli6'], axis='columns')
data = data.drop(['V. scophthalmi'], axis='columns')
data = data.drop(['간장질환'], axis='columns')
data = data.drop(['Trichodina sp.'], axis='columns')
data = data.drop(['Wgr2'], axis='columns')
data = data.drop(['궤양'], axis='columns')
data = data.drop(['ALT'], axis='columns')
data = data.drop(['PHOS'], axis='columns')
data = data.drop(['어체중(g)'], axis='columns')
data = data.drop(['전장(cm)'], axis='columns')
'''
# Out:
# "\ndata = data.drop(['Whkr4'], axis='columns')\ndata = data.drop(['체장(cm)'], axis='columns')\ndata = data.drop(['사료급이량'], axis='columns')\ndata = data.drop(['ALB'], axis='columns')\ndata = data.drop(['L. garvieae'], axis='columns')\ndata = data.drop(['Wlc1'], axis='columns')\ndata = data.drop(['P. damselae'], axis='columns')\ndata = data.drop(['Whr7'], axis='columns')\ndata = data.drop(['Wbkr2-2'], axis='columns')\ndata = data.drop(['안구질환'], axis='columns')\ndata = data.drop(['백신접종여부'], axis='columns')\ndata = data.drop(['Wlr2-2'], axis='columns')\ndata = data.drop(['사료종류'], axis='columns')\ndata = data.drop(['척추만곡'], axis='columns')\ndata = data.drop(['탈장'], axis='columns')\ndata = data.drop(['기타'], axis='columns')\ndata = data.drop(['Scuticocilliates'], axis='columns')\ndata = data.drop(['림포'], axis='columns')\ndata = data.drop(['Wlr8'], axis='columns')\ndata = data.drop(['Whi6-3'], axis='columns')\ndata = data.drop(['V. ichthyoenteri'], axis='columns')\ndata = data.drop(['Wlp1'], 
# ...

# %%
data.shape
# Out:
# (595, 102)

# %%
dataset = data.sample(frac=0.9, random_state=9)
data_unseen = data.drop(data.index)

dataset.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(dataset.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (536, 102)
# Unseen Data For Predictions: (0, 102)

# %%
from pycaret.classification import *
exp_mclf101 = setup(data = data, target = '결과', session_id=9)
# Out:
# <style type="text/css">
# #T_496ed_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_496ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_496ed_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_496ed_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_496ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_496ed_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_496ed_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_496ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_496ed_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_496ed_row1_col1" class="data row1 col1" >결과</td>
#     </tr>
#     <tr>
#       <th id="T_496ed_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_bff6e th {
#   text-align: left;
# }
# ...

# %%
plt.rc("font", family = "AppleGothic")
evaluate_model(best)
