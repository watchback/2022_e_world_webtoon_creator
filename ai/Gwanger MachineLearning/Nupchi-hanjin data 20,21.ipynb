# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
assert sys.version_info >= (3, 5)
import sklearn
assert sklearn.__version__ >= "0.20"
import numpy as np
import seaborn as sns
from sklearn.model_selection import StratifiedShuffleSplit
import warnings
warnings.filterwarnings(action='ignore')
plt.rcParams['font.family'] = 'AppleGothic' # For Mac

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
data = pd.read_csv("20-21.csv")

# %%
data.shape
# Out:
# (867, 84)

# %%
corr_matrix=data.corr()
print(corr_matrix["결과"].sort_values(ascending=False))
# Out:
# 결과                  1.000000
# Whkp2               0.508302
# Wlr1                0.435456
# Wlr2-1              0.409768
# Wsi2                0.404608
# Wgp2                0.346597
# Whki2-1             0.345537
# Wgr1                0.334204
# Wgi3                0.310523
# Whi3                0.282593
# 임상증상유무              0.272581
# Whi6-1              0.269589
# Wgc2                0.267527
# BUN                 0.266629
# Wsi3-1              0.263212
# Wlr6                0.254648
# Wli3-2              0.250913
# Wbkr5               0.235042
# Wli3-1              0.209158
# 신장질환                0.203318
# Wgr6                0.201309
# E. piscicida        0.195450
# Whkr7               0.191746
# Wbki3-2             0.188768
# 일순환량                0.184544
# 일평균폐사               0.183155
# 비장질환                0.180472
# Wbkr2-1             0.179448
# 복수                  0.172422
# ameoba              0.170614
# Wsr6                0.170436
# 심장질환                0.168995
# 빈혈                  0.166885
# Wbki3-1             0.166522
# 세균감염유무              0.164243
# Whi6-2              0.163247
# Wbkr6               0.151051
# 기생충유무               0.140044
# Wbkr1               0.137890
# Wlr4                0.121120
# Wsr5                0.119659
# 아가미부식               0.113082
# Wli6                0.105965
# V. scophthalmi      0.105536
# 간장질환                0.105075
# Trichodina sp.      0.104429
# Wgr2                0.103636
# 궤양                  0.103283
# Wgc1                0.091577
# gyrodactylus        0.091040
# Whki2-2             0.079776
# S. parauberis       0.075820
# Wlp1                0.073526
# Whkr6               0.070706
# V. ichthyoenteri    0.064150
# Whi6-3              0.056040
# Wlr8                0.047694
# 림포                  0.046196
# Scuticocilliates    0.041294
# 탈장                  0.038151
# 기타                  0.038151
# 척추만곡                0.038151
# 사료종류                0.028255
# Wlr2-2              0.022017
# 백신접종여부              0.019055
# 안구질환                0.015519
# Wbkr2-2             0.012634
# Whr7                0.001763
# P. damselae        -0.001587
# Wlc1               -0.005858
# L. garvieae        -0.049024
# ALB                -0.052077
# 사료급이량              -0.057968
# 체장(cm)             -0.093721
# ALT                -0.114623
# PHOS               -0.129633
# 어체중(g)             -0.149610
# 전장(cm)             -0.150692
# T P                -0.242565
# CHOL               -0.255146
# 수온                 -0.281723
# ALP                -0.300694
# Condition factor   -0.304833
# Whkr4                    NaN
# Name: 결과, dtype: float64

# %%
data = data.drop(['Whkr4'], axis='columns')
data = data.drop(['체장(cm)'], axis='columns')
data = data.drop(['사료급이량'], axis='columns')
data = data.drop(['ALB'], axis='columns')
data = data.drop(['L. garvieae'], axis='columns')
data = data.drop(['Wlc1'], axis='columns')
data = data.drop(['P. damselae'], axis='columns')
data = data.drop(['Whr7'], axis='columns')
data = data.drop(['Wbkr2-2'], axis='columns')
data = data.drop(['안구질환'], axis='columns')
data = data.drop(['백신접종여부'], axis='columns')
data = data.drop(['Wlr2-2'], axis='columns')
data = data.drop(['사료종류'], axis='columns')
data = data.drop(['척추만곡'], axis='columns')
data = data.drop(['탈장'], axis='columns')
data = data.drop(['기타'], axis='columns')
data = data.drop(['Scuticocilliates'], axis='columns')
data = data.drop(['림포'], axis='columns')
data = data.drop(['Wlr8'], axis='columns')
data = data.drop(['Whi6-3'], axis='columns')
data = data.drop(['V. ichthyoenteri'], axis='columns')
data = data.drop(['Wlp1'], axis='columns')
data = data.drop(['Whkr6'], axis='columns')
data = data.drop(['S. parauberis'], axis='columns')
data = data.drop(['Whki2-2'], axis='columns')
data = data.drop(['gyrodactylus'], axis='columns')
data = data.drop(['Wgc1'], axis='columns')
---------------------------------------------------
data = data.drop(['E. piscicida'], axis='columns')
data = data.drop(['Whkr7'], axis='columns')
data = data.drop(['Wbki3-2'], axis='columns')
data = data.drop(['일순환량'], axis='columns')
data = data.drop(['일평균폐사'], axis='columns')
data = data.drop(['복수'], axis='columns')
data = data.drop(['비장질환'], axis='columns')
data = data.drop(['Wbkr2-1'], axis='columns')
data = data.drop(['ameoba'], axis='columns')
data = data.drop(['Wsr6'], axis='columns')
data = data.drop(['심장질환'], axis='columns')
data = data.drop(['빈혈'], axis='columns')
data = data.drop(['Wbki3-1'], axis='columns')
data = data.drop(['세균감염유무'], axis='columns')
data = data.drop(['Whi6-2'], axis='columns')
data = data.drop(['Wbkr6'], axis='columns')
data = data.drop(['기생충유무'], axis='columns')
data = data.drop(['Wbkr1'], axis='columns')
data = data.drop(['Wlr4'], axis='columns')
data = data.drop(['Wsr5'], axis='columns')
data = data.drop(['아가미부식'], axis='columns')
data = data.drop(['Wli6'], axis='columns')
data = data.drop(['V. scophthalmi'], axis='columns')
data = data.drop(['간장질환'], axis='columns')
data = data.drop(['Trichodina sp.'], axis='columns')
data = data.drop(['Wgr2'], axis='columns')
data = data.drop(['궤양'], axis='columns')
data = data.drop(['ALT'], axis='columns')
data = data.drop(['PHOS'], axis='columns')
data = data.drop(['어체중(g)'], axis='columns')
data = data.drop(['전장(cm)'], axis='columns')

# %%
data.shape
# Out:
# (867, 26)

# %%
dataset = data.sample(frac=0.9, random_state=786)
data_unseen = data.drop(data.index)

dataset.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(dataset.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (780, 26)
# Unseen Data For Predictions: (0, 26)

# %%
from pycaret.classification import *
exp_mclf101 = setup(data = data, target = '결과', session_id=123)
# Out:
# <style type="text/css">
# #T_99ad4_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_99ad4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99ad4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_99ad4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99ad4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99ad4_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_99ad4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99ad4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_99ad4_row1_col1" class="data row1 col1" >결과</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99ad4_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_99ad4_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99ad4_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_99ad4_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99ad4_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_99ad4_row4_col1" class="data row4 col1" >(867, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99ad4_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_99ad4_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99ad4_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_99ad4_row6_col1" class="data row6 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99ad4_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_99ad4_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99ad4_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_99ad4_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99ad4_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_99ad4_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99ad4_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_99ad4_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_99ad4_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_99ad4_row11_col1" class="data row11 col1" >(606, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_99ad4_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_99ad4_row12_col1" class="data row12 col1" >(261, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_99ad4_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_99ad4_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_99ad4_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_99ad4_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_99ad4_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_99ad4_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_99ad4_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_99ad4_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_99ad4_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_99ad4_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_99ad4_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_99ad4_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_99ad4_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_99ad4_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_99ad4_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_99ad4_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_99ad4_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_99ad4_row21_col1" class="data row21 col1" >01d8</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_99ad4_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_99ad4_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_99ad4_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_99ad4_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_99ad4_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_99ad4_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_99ad4_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_99ad4_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_99ad4_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_99ad4_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_99ad4_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_99ad4_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_99ad4_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_99ad4_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_99ad4_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_99ad4_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99ad4_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_99ad4_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_99ad4_row30_col1" class="da

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_0b145 th {
#   text-align: left;
# }
# #T_0b145_row0_col0, #T_0b145_row1_col0, #T_0b145_row1_col1, #T_0b145_row1_col2, #T_0b145_row1_col3, #T_0b145_row1_col4, #T_0b145_row1_col5, #T_0b145_row1_col6, #T_0b145_row1_col7, #T_0b145_row2_col0, #T_0b145_row2_col1, #T_0b145_row2_col2, #T_0b145_row2_col3, #T_0b145_row2_col4, #T_0b145_row2_col5, #T_0b145_row2_col6, #T_0b145_row2_col7, #T_0b145_row3_col0, #T_0b145_row3_col1, #T_0b145_row3_col2, #T_0b145_row3_col3, #T_0b145_row3_col4, #T_0b145_row3_col5, #T_0b145_row3_col6, #T_0b145_row3_col7, #T_0b145_row4_col0, #T_0b145_row4_col1, #T_0b145_row4_col2, #T_0b145_row4_col3, #T_0b145_row4_col4, #T_0b145_row4_col5, #T_0b145_row4_col6, #T_0b145_row4_col7, #T_0b145_row5_col0, #T_0b145_row5_col1, #T_0b145_row5_col2, #T_0b145_row5_col3, #T_0b145_row5_col4, #T_0b145_row5_col5, #T_0b145_row5_col6, #T_0b145_row5_col7, #T_0b145_row6_col0, #T_0b145_row6_col1, #T_0b145_row6_col2, #T_0b145_row6_col3, #T_0b145_row6_col4, #T_0b145_row6_col5, #T_0b145_row6_col6, #T_0b145_row6_col7, #T_0b145_row7_col0, #T_0b145_row7_col1, #T_0b145_row7_col2, #T_0b145_row7_col3, #T_0b145_row7_col4, #T_0b145_row7_col5, #T_0b145_row7_col6, #T_0b145_row7_col7, #T_0b145_row8_col0, #T_0b145_row8_col1, #T_0b145_row8_col2, #T_0b145_row8_col3, #T_0b145_row8_col4, #T_0b145_row8_col5, #T_0b145_row8_col6, #T_0b145_row8_col7, #T_0b145_row9_col0, #T_0b145_row9_col1, #T_0b145_row9_col2, #T_0b145_row9_col3, #T_0b145_row9_col4, #T_0b145_row9_col5, #T_0b145_row9_col6, #T_0b145_row9_col7, #T_0b145_row10_col0, #T_0b145_row10_col1, #T_0b145_row10_col2, #T_0b145_row10_col3, #T_0b145_row10_col4, #T_0b145_row10_col5, #T_0b145_row10_col6, #T_0b145_row10_col7, #T_0b145_row11_col0, #T_0b145_row11_col1, #T_0b145_row11_col2, #T_0b145_row11_col3, #T_0b145_row11_col4, #T_0b145_row11_col5, #T_0b145_row11_col6, #T_0b145_row11_col7, #T_0b145_row12_col0, #T_0b145_row12_col1, #T_0b145_row12_col2, #T_0b145_row12_col3, #T_0b145_row12_col4, #T_0b145_row12_col5, #T_0b145_row12_col6, #T_0b145_row12_col7, #T_0b145_row13_col0, #T_0b145_row13_col1, #T_0b145_row13_col2, #T_0b145_row13_col3, #T_0b145_row13_col4, #T_0b145_row13_col5, #T_0b145_row13_col6, #T_0b145_row13_col7 {
#   text-align: left;
# }
# #T_0b145_row0_col1, #T_0b145_row0_col2, #T_0b145_row0_col3, #T_0b145_row0_col4, #T_0b145_row0_col5, #T_0b145_row0_col6, #T_0b145_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0b145_row0_col8, #T_0b145_row1_col8, #T_0b145_row2_col8, #T_0b145_row3_col8, #T_0b145_row4_col8, #T_0b145_row5_col8, #T_0b145_row6_col8, #T_0b145_row8_col8, #T_0b145_row10_col8, #T_0b145_row11_col8, #T_0b145_row12_col8, #T_0b145_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0b145_row7_col8, #T_0b145_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0b145">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b145_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0b145_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0b145_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0b145_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0b145_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0b145_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0b145_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0b145_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0b145_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b145_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_0b145_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0b145_row0_col1" class="data row0 col1" >0.7753</td>
#       <td id="T_0b145_row0_col2" class="data row0 col2" >0.8835</td>
#       <td id="T_0b145_row0_col3" class="data row0 col3" >0.7479</td>
#       <td id="T_0b145_row0_col4" class="data row0 col4" >0.7832</td>
#       <td id="T_0b145_row0_col5" class="data row0 col5" >0.7727</td>
#       <td id="T_0b145_row0_col6" class="data row0 col6" >0.6057</td>
#       <td id="T_0b145_row0_col7" class="data row0 col7" >0.6113</td>
#       <td id="T_0b145_row0_col8" class="data row0 col8" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_0b145_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_0b145_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_0b145_row1_col1" class="data row1 col1" >0.7638</td>
#       <td id="T_0b145_row1_col2" class="data row1 col2" >0.8796</td>
#       <td id="T_0b145_row1_col3" class="data row1 col3" >0.7238</td>
#       <td id="T_0b145_row1_col4" class="data row1 col4" >0.7697</td>
#       <td id="T_0b145_row1_col5" class="data row1 col5" >0.7610</td>
#       <td id="T_0b145_row1_col6" class="data row1 col6" >0.5790</td>
#       <td id="T_0b145_row1_col7" class="data row1 col7" >0.5847</td>
#       <td id="T_0b145_row1_col8" class="data row1 col8" >0.3660</td>
#     </tr>
#     <tr>
#       <th id="T_0b145_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_0b145_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0b145_row2_col1" class="data row2 col1" >0.7623</td>
#       <td id="T_0b145_row2_col2" class="data row2 col2" >0.8597</td>
#       <td id="T_0b145_row2_col3" class="data row2 col3" >0.6921</td>
#       <td id="T_0b145_row2_col4" class="data row2 col4" >0.7739</td>
#       <td id="T_0b145_row2_col5" class="data row2 col5" >0.7528</td>
#       <td id="T_0b145_row2_col6" class="data row2 col6" >0.5578</td>
#       <td id="T_0b145_row2_col7" class="data row2 col7" >0.5734</td>
#       <td id="T_0b145_row2_col8" class="data row2 col8" >0.1470</td>
#     </tr>
#     <tr>
#       <th id="T_0b145_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_0b145_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_0b145_row3_col1" class="data row3 col1" >0.7608</td>
#       <td id="T_0b145_row3_col2" class="data row3 col2" >0.8549</td>
#       <td id="T_0b145_row3_col3" class="data row3 col3" >0.7000</td>
#       <td id="T_0b145_row3_col4" class="data row3 col4" >0.7699</td>
#       <td id="T_0b145_row3_col5" class="data row3 col5" >0.7541</td>
#       <td id="T_0b145_row3_col6" class="data row3 col6" >0.5636</td>
#       <td id="T_0b145_row3_col7" class="data row3 col7" >0.5716</td>
#       <td id="T_0b145_row3_col8" class="data row3 col8" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_0b145_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_0b145_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0b145_row4_col1" class="data row4 col1" >0.7556</td>
#       <td id="T_0b145_row4_col2" class="data row4 col2" >0.8558</td>
#       <td id="T_0b145_row4_col3" class="data row4 col3" >0.6992</td>
#       <td id="T_0b145_row4_col4" class="data row4 col4" >0.7614</td>
#       <td id="T_0b145_row4_col5" class="data row4 col5" >0.7497</td>
#       <td id="T_0b145_row4_col6" class="data row4 col6" >0.5538</td>
#       <td id="T_0b145_row4_col7" class="data row4 col7" >0.5618</td>
#       <td id="T_0b145_row4_col8" class="data row4 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_0b145_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_0b145_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_0b145_row5_col1" class="data row5 col1" >0.7508</td>
#       <td id="T_0b145_row5_col2" class="data row5 col2" >0.8671</td>
#       <td id="T_0b145_row5_col3" class="data row5 col3" >0.6648</td>
#       <td id="T_0b145_row5_col4" class="data row5 col4" >0.7705</td>
#       <td id="T_0b145_row5_col5" class="data row5 col5" >0.7381</td>
#       <td id="T_0b145_row5_col6" class="data row5 col6" >0.5306</td>
#       <td id="T_0b145_row5_col7" class="data row5 col7" >0.5508</td
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.7121e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.81677e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.10125e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.76414e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.83052e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.95542e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.78178e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute standard_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_coef_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute average_intercept_ was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.05161e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.18864e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.83454e-08): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/utils/deprecation.py:101: FutureWarning: The outputs_2d_ attribute is deprecated in version 0.22 and will be removed in version 0.24. It is equivalent to n_outputs_ > 1.
#   warnings.warn(msg, category=FutureWarning)
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/pycaret/lib/python3.8/site-packages/sklearn/metrics/_classification.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)

# %%
plt.rc("font", family = "AppleGothic")
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
