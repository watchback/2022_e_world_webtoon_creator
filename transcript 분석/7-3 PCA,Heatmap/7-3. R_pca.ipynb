# %%
import seaborn as sns
import pandas as pd
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
from pca import pca
import seaborn as sns

# %%
data = pd.read_csv('/Users/csb/file.csv',sep=',') # 파일 불러오기

# %%
data
# Out:
#   Unnamed: 0       PC1       PC2
# 0       D4B1 -0.307970  0.352060
# 1       D4B2 -0.337621  0.234293
# 2       D4B3 -0.330967  0.344902
# 3       D4B4 -0.331829  0.403674
# 4       D4L1 -0.340100 -0.390752
# 5       D4L2 -0.359056 -0.244524
# 6       D4L3 -0.325435 -0.387697
# 7       D4L4 -0.360239 -0.385788
# 8       D4S1 -0.302072  0.166223

# %%
data = data.set_index("Unnamed: 0")
data
# Out:
#                  PC1       PC2
# Unnamed: 0
# D4B1       -0.307970  0.352060
# D4B2       -0.337621  0.234293
# D4B3       -0.330967  0.344902
# D4B4       -0.331829  0.403674
# D4L1       -0.340100 -0.390752
# D4L2       -0.359056 -0.244524
# D4L3       -0.325435 -0.387697
# D4L4       -0.360239 -0.385788
# D4S1       -0.302072  0.166223

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(14,7))
sns.scatterplot(data=data,x='PC1',y='PC2',hue=data.index, s=200) # absolute, All genes
for line in range(0,data.shape[0]):
     plt.text(data.PC1[line]+0.0005, data.PC2[line], data.index[line], horizontalalignment='left', size='medium', color='black', weight='semibold')

plt.show()
