# %%
import seaborn as sns
import pandas as pd
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
from pca import pca
import seaborn as sns

# %%
'''r_all = pd.read_csv('/Users/csb/Desktop/rpca.csv',sep=',',index_col=0) # 파일 불러오기
r_all['category'] = ['B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S','B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S']
r_log = pd.read_csv('/Users/csb/Desktop/rlogpca.csv',sep=',',index_col=0) # 파일 불러오기
r_log['category'] = ['B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S','B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S']
r_cutoff = pd.read_csv('/Users/csb/Desktop/rcutpca.csv',sep=',',index_col=0) # 파일 불러오기
r_cutoff['category'] = ['B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S','B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S']
'''
r_log_cutoff = pd.read_csv('/Users/csb/logcut1pca.csv',sep=',',index_col=0) # 파일 불러오기
r_log_cutoff['category'] = ['B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S','B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S']

# %%
r_cutoff5 = pd.read_csv('/Users/csb/cut5pca.csv',sep=',',index_col=0) # 파일 불러오기
r_cutoff5['category'] = ['B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S','B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S']
r_logcutoff5 = pd.read_csv('/Users/csb/logcut5pca.csv',sep=',',index_col=0) # 파일 불러오기
r_logcutoff5['category'] = ['B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S','B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S']
r_cutoff10 = pd.read_csv('/Users/csb/cut10pca.csv',sep=',',index_col=0) # 파일 불러오기
r_cutoff10['category'] = ['B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S','B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S']
r_logcutoff10 = pd.read_csv('/Users/csb/logcut10pca.csv',sep=',',index_col=0) # 파일 불러오기
r_logcutoff10['category'] = ['B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S','B', 'B', 'B', 'B', 'L', 'L', 'L', 'L', 'S']

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(data=r_logcutoff5,x='PC1',y='PC2',hue=r_logcutoff5['category'], s=200) # absolute, All genes
plt.xlabel('PC1 (63.7%)', fontsize=15)
plt.ylabel('PC2 (11.9%)', fontsize=15)
for line in range(0,r_logcutoff5.shape[0]):
     plt.text(r_logcutoff5.PC1[line]+0.005, r_logcutoff5.PC2[line], r_logcutoff5.index[line][1:], horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('/Users/csb/Desktop/r_logcutoff5.jpg')
plt.show()

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(data=r_all,x='PC1',y='PC2',hue=r_all['category'], s=200) # absolute, All genes
plt.xlabel('PC1 (96.1%)', fontsize=15)
plt.ylabel('PC2 (3.53%)', fontsize=15)
for line in range(0,r_all.shape[0]):
     plt.text(r_all.PC1[line]+0.005, r_all.PC2[line], r_all.index[line][1:], horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('/Users/csb/Desktop/all.jpg')
plt.show()

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(data=r_log,x='PC1',y='PC2',hue=r_log['category'], s=200) # absolute, All genes
plt.xlabel('PC1 (76.8%)', fontsize=15)
plt.ylabel('PC2 (5.48%)', fontsize=15)
for line in range(0,r_log.shape[0]):
     plt.text(r_log.PC1[line]+0.0005, r_log.PC2[line], r_log.index[line][1:], horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('/Users/csb/Desktop/log.jpg')
plt.show()

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(data=r_cutoff,x='PC1',y='PC2',hue=r_cutoff['category'], s=200) # absolute, All genes
plt.xlabel('PC1 (96.1%)', fontsize=15)
plt.ylabel('PC2 (3.53%)', fontsize=15)
for line in range(0,r_cutoff.shape[0]):
     plt.text(r_cutoff.PC1[line]+0.005, r_cutoff.PC2[line], r_cutoff.index[line][1:], horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('/Users/csb/Desktop/cutoff.jpg')
plt.show()

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(data=r_log_cutoff,x='PC1',y='PC2',hue=r_log_cutoff['category'], s=200) # absolute, All genes
plt.xlabel('PC1 (71.9%)', fontsize=15)
plt.ylabel('PC2 (6.98%)', fontsize=15)
for line in range(0,r_log_cutoff.shape[0]):
     plt.text(r_log_cutoff.PC1[line]+0.0005, r_log_cutoff.PC2[line], r_log_cutoff.index[line][1:], horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('/Users/csb/Desktop/cutoff_log.jpg')
plt.show()
